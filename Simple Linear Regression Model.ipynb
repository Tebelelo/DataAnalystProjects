# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
Ice_Cream_Sales = pd.read_csv("Ice Cream Sales - temperatures.csv")
Ice_Cream_Sales.head()
# Out:
#    Temperature  Ice Cream Profits
# 0           39              13.17
# 1           40              11.88
# 2           41              18.82
# 3           42              18.65
# 4           43              17.02

# %%
plt.scatter(x = Ice_Cream_Sales['Temperature'], y = Ice_Cream_Sales['Ice Cream Profits'])
plt.xlabel('Temperature')
plt.ylabel('Profits')
plt.show()

# %%
Ice_Cream_Sales.corr()
# Out:
#                    Temperature  Ice Cream Profits
# Temperature           1.000000           0.988446
# Ice Cream Profits     0.988446           1.000000

# %% [markdown]
# ## LINEAR REGRESSION MODEL

# %%
from sklearn.model_selection import train_test_split
from sklearn import datasets, linear_model, metrics

# %%
x = Ice_Cream_Sales['Temperature'].values
y = Ice_Cream_Sales['Ice Cream Profits'].values

# %%
#Splitting Data into Training and Testing Sets
x_train, x_test,y_train, y_test = train_test_split(x, y,test_size=0.4, random_state=1)
print('Training size')
print(y_train.shape)
print(" ")
print('Testing size')
print(y_test.shape)
# Out:
# Training size
# (219,)
#
# Testing size
# (146,)

# %% [markdown]
# Here it divides the data into training and testing sets using the train_test_split() function from scikit-learn. The test_size parameter specifies that 40% of the data should be used for testing.The random_state is a pseudo-random number parameter that allows you to reproduce the same train test split each time you run the code.

# %%
#Creating and Training the Linear Regression Model
reg_model = linear_model.LinearRegression()
reg_model.fit(x_train.reshape(-1,1),y_train.reshape(-1,1))
# Out:
# LinearRegression()

# %%
#Model for training
print('Coefficient: ', reg_model.coef_)
print('Intercept: ', reg_model.intercept_)
# Out:
# Coefficient:  [[1.18719774]]
# Intercept:  [-33.44588959]

# %%
#Evaluating the model
reg_model.predict(x_test.reshape(-1,1))
# Out:
# array([[79.33789525],
#        [54.40674281],
#        [52.03234734],
#        [52.03234734],
#        [68.65311564],
#        [71.02751111],
#        [61.52992922],
#        [56.78113828],
#        [78.15069752],
#        [17.60361302],
#        [67.4659179 ],
#        [74.58910431],
#        [59.15553375],
#        [42.53476546],
#        [46.09635867],
#        [62.71712696],
#        [84.08668619],
#        [37.78597452],
#        [54.40674281],
#        [72.21470884],
#        [56.78113828],
#        [41.34756773],
#        [60.34273149],
#        [62.71712696],
#        [44.90916093],
#        [54.40674281],
#        [50.84514961],
#        [46.09635867],
#        [60.34273149],
#        [41.34756773],
#        [17.60361302],
#        [47.2835564 ],
#        [44.90916093],
#        [50.84514961],
#        [23.5396017 ],
#        [79.33789525],
#        [49.65795187],
#        [36.59877678],
#        [44.90916093],
#        [57.96833602],
#        [21.16520623],
#        [23.5396017 ],
#        [57.96833602],
#        [42.53476546],
#        [66.27872016],
#        [30.66278811],
#        [72.21470884],
#        [52.03234734],
#        [65.09152243],
#        [54.40674281],
#        [67.4659179 ],
#        [36.59877678],
#        [60.34273149],
#        [63.90432469],
#        [22.35240396],
#        [36.59877678],
#        [60.34273149],
#        [54.40674281],
#        [44.90916093],
#        [65.09152243],
#        [60.34273149],
#        [67.4659179 ],
#        [18.79081076],
#        [50.84514961],
#        [84.08668619],
#        [41.34756773],
#        [61.52992922],
#        [63.90432469],
#        [53.21954508],
#        [73.40190658],
#        [43.7219632 ],
#        [27.1011949 ],
#        [65.09152243],
#        [38.97317225],
#        [57.96833602],
#        [60.34273149],
#        [38.97317225],
#        [73.40190658],
#        [79.33789525],
#        [47.2835564 ],
#        [57.96833602],
#        [78.15069752],
#        [30.66278811],
#        [43.7219632 ],
#        [43.7219632 ],
#        [69.84031337],
#        [35.41157905],
#        [21.16520623],
#        [66.27872016],
#        [67.4659179 ],
#        [59.15553375],
#        [86.46108166],
#        [80.52509299],
#        [28.28839264],
#        [40.16036999],
#        [35.41157905],
#        [50.84514961],
#        [48.47075414],
#        [66.27872016],
#        [61.52992922],
#        [67.4659179 ],
#        [56.78113828],
#        [66.27872016],
#        [47.2835564 ],
#        [46.09635867],
#        [48.47075414],
#        [38.97317225],
#        [41.34756773],
#        [57.96833602],
#        [69.84031337],
#        [57.96833602],
#        [55.59394055],
#        [47.2835564 ],
#        [23.5396017 ],
#        [25.91399717],
#        [62.71712696],
#        [57.96833602],
#        [44.90916093],
#        [33.03718358],
#        [42.53476546],
#        [44.90916093],
#        [19.97800849],
#        [49.65795187],
#        [23.5396017 ],
#        [44.90916093],
#        [57.96833602],
#        [12.85482208],
#        [52.03234734],
#        [43.7219632 ],
#        [67.4659179 ],
#        [52.03234734],
#        [37.78597452],
#        [30.66278811],
#        [50.84514961],
#        [75.77630205],
#        [30.66278811],
#        [54.40674281],
#        [67.4659179 ],
#        [53.21954508],
#        [50.84514961],
#        [59.15553375],
#        [65.09152243],
#        [52.03234734],
#        [50.84514961],
#        [42.53476546],
#        [29.47559037]])

# %%
print(y_test)
# Out:
# [80.98 55.28 51.26 50.79 69.66 69.67 63.46 59.41 80.94 15.88 61.82 81.81
#  61.22 44.85 48.65 62.32 87.08 40.95 54.36 71.51 59.69 39.17 59.69 62.36
#  48.26 50.65 46.74 45.26 59.93 41.58 17.02 49.37 45.07 49.6  26.41 80.75
#  52.67 37.5  40.65 57.47 21.25 25.01 60.86 40.28 68.54 31.94 73.16 51.55
#  63.29 50.64 64.31 36.71 64.82 64.97 22.12 29.69 67.42 54.28 45.05 64.38
#  59.49 67.93 19.07 55.04 89.29 40.59 61.82 66.15 51.82 75.11 42.1  21.93
#  62.58 39.53 56.33 61.71 38.16 75.94 78.2  45.89 56.33 75.7  33.58 45.38
#  43.28 70.43 36.11 19.81 65.41 65.99 60.89 85.02 82.83 30.67 40.19 35.13
#  52.17 48.77 65.12 61.59 68.28 56.59 65.4  47.73 44.85 42.5  39.42 44.15
#  56.43 68.   55.07 55.34 47.35 24.22 25.68 62.12 58.72 42.16 33.22 40.57
#  46.74 22.34 49.12 23.78 47.36 59.87 13.17 48.96 42.72 70.3  53.57 36.25
#  30.09 54.59 77.41 33.71 55.52 69.71 53.21 53.77 57.93 60.78 53.59 53.04
#  44.1  32.6 ]

# %%
#Testing Model accuracy
reg_model.score(x_test.reshape(-1,1) ,y_test.reshape(-1,1))
# Out:
# 0.9801811291503565

# %% [markdown]
# Evaluating the model’s performance by outputing the regression coefficients and calculating the variance score, which measures the proportion of explained variance. The model.score automates the prediction of your data using X_test and compares it with Y_test and by default uses the R-squared metric to so. A score of 1 indicates perfect prediction.
#
# Therefore the accuracy of the model is 98%.
